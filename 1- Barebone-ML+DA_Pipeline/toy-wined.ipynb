# %%
from sklearn import datasets
import pandas as pd

# %%
# Load Wine dataset
# Para descripcion de features y de dataset ver appendix A.

X , y = datasets.load_wine(return_X_y=True,as_frame=True)

print(type(X), type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'>

# %% [markdown]
# # Dataset Pipeline : Exploracion

# %%
print( X.shape , y.shape )
# Out:
# (178, 13) (178,)

# %%
X.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# dtype: object

# %%
y.dtypes
# Out:
# dtype('int32')

# %%
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int32

# %%
# Cheking missin values. As it's a tidy dataset no missin values are expected. 
X.isna().values.any()
# Out:
# False

# %% [markdown]
# **Quicktake** <br>
# Input features<br>
# All variables are numerical and continous.
#
# Output features<br>
# Categorical (nominal). Label categorizes wine in three diferent categories. variable is latter coded as dictionary

# %%
import seaborn as sns

g = sns.PairGrid(X)
g.map(sns.scatterplot)

# %% [markdown]
# **QuickTake** <br>
# A simple vista hay muy pocas relaciones lineales entre features. Esto es esperable because it's a toy dataset cherrypicked para clasificacion.

# %%
from sklearn import preprocessing

standarizer = preprocessing.StandardScaler().fit(X)

print("Mean")
print(standarizer.mean_)
print("Scaler")
print(standarizer.scale_)
# Out:
# Mean
# [1.30006180e+01 2.33634831e+00 2.36651685e+00 1.94949438e+01
#  9.97415730e+01 2.29511236e+00 2.02926966e+00 3.61853933e-01
#  1.59089888e+00 5.05808988e+00 9.57449438e-01 2.61168539e+00
#  7.46893258e+02]
# Scaler
# [8.09542915e-01 1.11400363e+00 2.73572294e-01 3.33016976e+00
#  1.42423077e+01 6.24090564e-01 9.96048950e-01 1.24103260e-01
#  5.70748849e-01 2.31176466e+00 2.27928607e-01 7.07993265e-01
#  3.14021657e+02]

# %%
X_std = standarizer.transform(X)

# %%
X_std = pd.DataFrame(X_std)
X_std.columns = X.columns

# %%
X_std.head()
# Out:
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1  0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2  0.196879    0.021231  1.109334          -0.268738   0.088358
# 3  1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4  0.295700    0.227694  1.840403           0.451946   1.281985
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.808997    1.034819             -0.659563         1.224884
# 1       0.568648    0.733629             -0.820719        -0.544721
# 2       0.808997    1.215533             -0.498407         2.135968
# 3       2.491446    1.466525             -0.981875         1.032155
# 4       0.808997    0.663351              0.226796         0.401404
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# 0         0.251717  0.362177                      1.847920  1.013009
# ...

# %% [markdown]
# # Model pipeline

# %% [markdown]
# **Quicktake**
#
# ML problem type: Classification
# Learning Type: Supervised
#
# Input variables / features:
# Output variables / target:  wine categories.

# %% [markdown]
# # Appendix A

# %% [markdown]
# Descripcion de features en  https://scikit-learn.org/stable/datasets/toy_dataset.html#wine-dataset
#
# Tipo de dataset: Tabular
# Formato de data set tabular: Tipo long (https://seaborn.pydata.org/tutorial/data_structure.html)

# %% [markdown]
# # Appendix B

# %% [markdown]
# # Appendix C
